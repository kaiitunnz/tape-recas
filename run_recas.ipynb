# %%
SEED = None
RUNS = 4

# %% [markdown]
# # Dataset: tape-arxiv-2023

# %%
dataset = "arxiv_2023"

# %% [markdown]
# ## Run ReCaS-Mixed

# %%
params_path = "core/CaS/recas_params_default.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.recas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': True}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': True}
# params_dict: {'alpha': 0.20305970175605254, 'A': 1, 'num_propagations': 50, 'labels': ['train']}
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': True}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': True}
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.recas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': False}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': False}
# params_dict: {'alpha': 0.20305970175605254, 'A': 1, 'num_propagations': 50, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': False}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': False}
# ...

# %% [markdown]
# ## Run ReCaS-SC

# %%
params_path = "core/CaS/recas_params_sc.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': True}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': True}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': True}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': True}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': True}]
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train', 'valid']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': False}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train', 'valid']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': False}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': False}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': False}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': False}]
# ...

# %% [markdown]
# ## Run ReCaS-SCS

# %%
params_path = "core/CaS/recas_params_scs.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': True}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': True}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': True}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': True}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': True}]
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train', 'valid']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': False}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train', 'valid']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': False}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': False}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': False}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': False}]
# ...

# %% [markdown]
# ## Run ReCaS-CSCS

# %%
params_path = "core/CaS/recas_params_cscs.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': True}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': True}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': True}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': True}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': True}]
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train', 'valid']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': False}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train', 'valid']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': False}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': False}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': False}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': False}]
# ...

# %% [markdown]
# # Dataset: ogbn-arxiv

# %%
dataset = "ogbn-arxiv"

# %% [markdown]
# ## Run ReCaS-Mixed

# %%
params_path = "core/CaS/recas_params_default.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.recas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': True}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': True}
# params_dict: {'alpha': 0.20305970175605254, 'A': 1, 'num_propagations': 50, 'labels': ['train']}
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': True}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': True}
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.recas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': False}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': False}
# params_dict: {'alpha': 0.20305970175605254, 'A': 1, 'num_propagations': 50, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': False}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': False}
# ...

# %% [markdown]
# ## Run ReCaS-SC

# %%
params_path = "core/CaS/recas_params_sc.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': True}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': True}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': True}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': True}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': True}]
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train', 'valid']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': False}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train', 'valid']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': False}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': False}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': False}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': False}]
# ...

# %% [markdown]
# ## Run ReCaS-SCS

# %%
params_path = "core/CaS/recas_params_scs.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': True}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': True}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': True}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': True}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': True}]
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train', 'valid']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': False}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train', 'valid']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': False}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': False}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': False}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': False}]
# ...

# %% [markdown]
# ## Run ReCaS-CSCS

# %%
params_path = "core/CaS/recas_params_cscs.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': True}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': True}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': True}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': True}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': True}]
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train', 'valid']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': False}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train', 'valid']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': False}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': False}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': False}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': False}]
# ...

# %% [markdown]
# # Dataset: pubmed

# %%
dataset = "pubmed"

# %% [markdown]
# ## Run ReCaS-Mixed

# %%
params_path = "core/CaS/recas_params_default.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.recas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': True}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': True}
# params_dict: {'alpha': 0.20305970175605254, 'A': 1, 'num_propagations': 50, 'labels': ['train']}
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': True}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': True}
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.recas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': False}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': False}
# params_dict: {'alpha': 0.20305970175605254, 'A': 1, 'num_propagations': 50, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': False}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': False}
# ...

# %% [markdown]
# ## Run ReCaS-SC

# %%
params_path = "core/CaS/recas_params_sc.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': True}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': True}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': True}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': True}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': True}]
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train', 'valid']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': False}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train', 'valid']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': False}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': False}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': False}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': False}]
# ...

# %% [markdown]
# ## Run ReCaS-SCS

# %%
params_path = "core/CaS/recas_params_scs.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': True}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': True}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': True}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': True}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': True}]
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train', 'valid']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': False}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train', 'valid']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': False}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': False}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': False}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': False}]
# ...

# %% [markdown]
# ## Run ReCaS-CSCS

# %%
params_path = "core/CaS/recas_params_cscs.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': True}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': True}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': True}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': True}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': True}]
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train', 'valid']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': False}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train', 'valid']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': False}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': False}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': False}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': False}]
# ...

# %% [markdown]
# # Dataset: cora

# %%
dataset = "cora"

# %% [markdown]
# ## Run ReCaS-Mixed

# %%
params_path = "core/CaS/recas_params_default.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.recas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': True}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': True}
# params_dict: {'alpha': 0.20305970175605254, 'A': 1, 'num_propagations': 50, 'labels': ['train']}
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': True}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': True}
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.recas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': False}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': False}
# params_dict: {'alpha': 0.20305970175605254, 'A': 1, 'num_propagations': 50, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': False}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': False}
# ...

# %% [markdown]
# ## Run ReCaS-SC

# %%
params_path = "core/CaS/recas_params_sc.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': True}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': True}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': True}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': True}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': True}]
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train', 'valid']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': False}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train', 'valid']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': False}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': False}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': False}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': False}]
# ...

# %% [markdown]
# ## Run ReCaS-SCS

# %%
params_path = "core/CaS/recas_params_scs.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': True}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': True}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': True}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': True}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': True}]
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train', 'valid']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': False}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train', 'valid']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': False}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': False}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': False}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': False}]
# ...

# %% [markdown]
# ## Run ReCaS-CSCS

# %%
params_path = "core/CaS/recas_params_cscs.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': True}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': True}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': True}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': True}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': True}]
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runReCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.recas_params_path $params_path
# !python -m core.runReCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.recas_params_path $params_path
# Out:
# params_list: [{'alpha': 0.29944542437345584, 'A': 2, 'num_propagations': 40, 'labels': ['train', 'valid']}, {'alpha1': 0.18436069813505415, 'alpha2': 0.23145032728908918, 'A1': 1, 'A2': 1, 'num_propagations1': 70, 'num_propagations2': 90, 'train_only': False}]
# params_list: [{'alpha': 0.3724259357644544, 'A': 0, 'num_propagations': 70, 'labels': ['train', 'valid']}, {'alpha': 0.5030743469731582, 'A': 2, 'num_propagations': 20, 'train_only': False}]
# params_list: [{'alpha1': 0.8259455813628246, 'alpha2': 0.20525290294508572, 'A1': 1, 'A2': 2, 'num_propagations1': 30, 'num_propagations2': 20, 'train_only': False}, {'alpha': 0.7822835507681539, 'A': 2, 'num_propagations': 60, 'train_only': False}]
# params_list: [{'alpha': 0.3063364104182211, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}, {'alpha': 0.8968500360548572, 'A': 2, 'num_propagations': 50, 'train_only': False}]
# ...
