# %%
SEED = None
RUNS = 4

# %% [markdown]
# # Dataset: tape-arxiv-2023

# %%
dataset = "arxiv_2023"

# %% [markdown]
# ## Run CaS-Mixed

# %%
params_path = "core/CaS/cas_params.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': True}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': True}
# params_dict: {'alpha': 0.20305970175605254, 'A': 1, 'num_propagations': 50, 'labels': ['train']}
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': True}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': True}
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': False}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': False}
# params_dict: {'alpha': 0.20305970175605254, 'A': 1, 'num_propagations': 50, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': False}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': False}
# ...

# %% [markdown]
# ## Run CaS-CS

# %%
params_path = "core/CaS/cas_params_cs.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.7483435593775988, 'alpha2': 0.21628088952254101, 'A1': 1, 'A2': 0, 'num_propagations1': 30, 'num_propagations2': 60, 'device': 0, 'train_only': True}
# params_dict: {'alpha1': 0.776120880650956, 'alpha2': 0.2701688354751819, 'A1': 2, 'A2': 0, 'num_propagations1': 50, 'num_propagations2': 60, 'device': 0, 'train_only': True}
# params_dict: {'alpha1': 0.21797666733990023, 'alpha2': 0.6040973013321987, 'scale': 7.121815021319951, 'A1': 0, 'A2': 2, 'num_propagations1': 20, 'num_propagations2': 30, 'device': 0, 'train_only': True}
# params_dict: {'alpha1': 0.1664209110517884, 'alpha2': 0.821504420722932, 'A1': 0, 'A2': 2, 'num_propagations1': 10, 'num_propagations2': 60, 'device': 0, 'train_only': True}
# params_dict: {'alpha1': 0.7483435593775988, 'alpha2': 0.21628088952254101, 'A1': 1, 'A2': 0, 'num_propagations1': 30, 'num_propagations2': 60, 'device': 0, 'train_only': True}
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.7483435593775988, 'alpha2': 0.21628088952254101, 'A1': 1, 'A2': 0, 'num_propagations1': 30, 'num_propagations2': 60, 'device': 0, 'train_only': False}
# params_dict: {'alpha1': 0.776120880650956, 'alpha2': 0.2701688354751819, 'A1': 2, 'A2': 0, 'num_propagations1': 50, 'num_propagations2': 60, 'device': 0, 'train_only': False}
# params_dict: {'alpha1': 0.21797666733990023, 'alpha2': 0.6040973013321987, 'scale': 7.121815021319951, 'A1': 0, 'A2': 2, 'num_propagations1': 20, 'num_propagations2': 30, 'device': 0, 'train_only': False}
# params_dict: {'alpha1': 0.1664209110517884, 'alpha2': 0.821504420722932, 'A1': 0, 'A2': 2, 'num_propagations1': 10, 'num_propagations2': 60, 'device': 0, 'train_only': False}
# params_dict: {'alpha1': 0.7483435593775988, 'alpha2': 0.21628088952254101, 'A1': 1, 'A2': 0, 'num_propagations1': 30, 'num_propagations2': 60, 'device': 0, 'train_only': False}
# ...

# %% [markdown]
# ## Run CaS-S

# %%
params_path = "core/CaS/cas_params_s.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha': 0.23864459546776673, 'A': 1, 'num_propagations': 80, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.6536925410715113, 'A': 2, 'num_propagations': 10, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.500927654473835, 'A': 0, 'num_propagations': 20, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.2776057502980387, 'A': 1, 'num_propagations': 100, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.23864459546776673, 'A': 1, 'num_propagations': 80, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.6536925410715113, 'A': 2, 'num_propagations': 10, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.500927654473835, 'A': 0, 'num_propagations': 20, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.2776057502980387, 'A': 1, 'num_propagations': 100, 'device': 0, 'labels': ['train']}
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha': 0.23864459546776673, 'A': 1, 'num_propagations': 80, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.6536925410715113, 'A': 2, 'num_propagations': 10, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.500927654473835, 'A': 0, 'num_propagations': 20, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.2776057502980387, 'A': 1, 'num_propagations': 100, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.23864459546776673, 'A': 1, 'num_propagations': 80, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.6536925410715113, 'A': 2, 'num_propagations': 10, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.500927654473835, 'A': 0, 'num_propagations': 20, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.2776057502980387, 'A': 1, 'num_propagations': 100, 'device': 0, 'labels': ['train', 'valid']}
# ...

# %% [markdown]
# # Dataset: ogbn-arxiv

# %%
dataset = "ogbn-arxiv"

# %% [markdown]
# ## Run CaS-Mixed

# %%
params_path = "core/CaS/cas_params.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': True}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': True}
# params_dict: {'alpha': 0.20305970175605254, 'A': 1, 'num_propagations': 50, 'labels': ['train']}
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': True}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': True}
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': False}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': False}
# params_dict: {'alpha': 0.20305970175605254, 'A': 1, 'num_propagations': 50, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': False}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': False}
# ...

# %% [markdown]
# ## Run CaS-CS

# %%
params_path = "core/CaS/cas_params_cs.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.2910838402269896, 'alpha2': 0.9217235195561917, 'A1': 1, 'A2': 2, 'num_propagations1': 70, 'num_propagations2': 40, 'device': 0, 'train_only': True}
# params_dict: {'alpha1': 0.9657666382916503, 'alpha2': 0.7002381520796033, 'A1': 1, 'A2': 0, 'num_propagations1': 60, 'num_propagations2': 70, 'device': 0, 'train_only': True}
# params_dict: {'alpha1': 0.8708299272484008, 'alpha2': 0.7351196469859955, 'A1': 2, 'A2': 0, 'num_propagations1': 20, 'num_propagations2': 40, 'device': 0, 'train_only': True}
# params_dict: {'alpha1': 0.9504568397674427, 'alpha2': 0.6940824984831212, 'A1': 2, 'A2': 0, 'num_propagations1': 50, 'num_propagations2': 40, 'device': 0, 'train_only': True}
# params_dict: {'alpha1': 0.2910838402269896, 'alpha2': 0.9217235195561917, 'A1': 1, 'A2': 2, 'num_propagations1': 70, 'num_propagations2': 40, 'device': 0, 'train_only': True}
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.2910838402269896, 'alpha2': 0.9217235195561917, 'A1': 1, 'A2': 2, 'num_propagations1': 70, 'num_propagations2': 40, 'device': 0, 'train_only': False}
# params_dict: {'alpha1': 0.9657666382916503, 'alpha2': 0.7002381520796033, 'A1': 1, 'A2': 0, 'num_propagations1': 60, 'num_propagations2': 70, 'device': 0, 'train_only': False}
# params_dict: {'alpha1': 0.8708299272484008, 'alpha2': 0.7351196469859955, 'A1': 2, 'A2': 0, 'num_propagations1': 20, 'num_propagations2': 40, 'device': 0, 'train_only': False}
# params_dict: {'alpha1': 0.9504568397674427, 'alpha2': 0.6940824984831212, 'A1': 2, 'A2': 0, 'num_propagations1': 50, 'num_propagations2': 40, 'device': 0, 'train_only': False}
# params_dict: {'alpha1': 0.2910838402269896, 'alpha2': 0.9217235195561917, 'A1': 1, 'A2': 2, 'num_propagations1': 70, 'num_propagations2': 40, 'device': 0, 'train_only': False}
# ...

# %% [markdown]
# ## Run CaS-S

# %%
params_path = "core/CaS/cas_params_s.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha': 0.9007411544398796, 'A': 2, 'num_propagations': 100, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.8129322565378936, 'A': 0, 'num_propagations': 50, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.8143537137235631, 'A': 0, 'num_propagations': 30, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.7799946491371338, 'A': 2, 'num_propagations': 30, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.9007411544398796, 'A': 2, 'num_propagations': 100, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.8129322565378936, 'A': 0, 'num_propagations': 50, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.8143537137235631, 'A': 0, 'num_propagations': 30, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.7799946491371338, 'A': 2, 'num_propagations': 30, 'device': 0, 'labels': ['train']}
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha': 0.9007411544398796, 'A': 2, 'num_propagations': 100, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.8129322565378936, 'A': 0, 'num_propagations': 50, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.8143537137235631, 'A': 0, 'num_propagations': 30, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.7799946491371338, 'A': 2, 'num_propagations': 30, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.9007411544398796, 'A': 2, 'num_propagations': 100, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.8129322565378936, 'A': 0, 'num_propagations': 50, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.8143537137235631, 'A': 0, 'num_propagations': 30, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.7799946491371338, 'A': 2, 'num_propagations': 30, 'device': 0, 'labels': ['train', 'valid']}
# ...

# %% [markdown]
# # Dataset: pubmed

# %%
dataset = "pubmed"

# %% [markdown]
# ## Run CaS-Mixed

# %%
params_path = "core/CaS/cas_params.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': True}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': True}
# params_dict: {'alpha': 0.20305970175605254, 'A': 1, 'num_propagations': 50, 'labels': ['train']}
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': True}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': True}
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': False}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': False}
# params_dict: {'alpha': 0.20305970175605254, 'A': 1, 'num_propagations': 50, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': False}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': False}
# ...

# %% [markdown]
# ## Run CaS-CS

# %%
params_path = "core/CaS/cas_params_cs.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.5454773213405756, 'alpha2': 0.16550248474176055, 'A1': 1, 'A2': 1, 'num_propagations1': 50, 'num_propagations2': 100, 'device': 0, 'train_only': True}
# params_dict: {'alpha1': 0.524166574314263, 'alpha2': 0.13874388251454498, 'A1': 1, 'A2': 1, 'num_propagations1': 100, 'num_propagations2': 30, 'device': 0, 'train_only': True}
# params_dict: {'alpha1': 0.3190693285636486, 'alpha2': 0.13447222770393363, 'A1': 1, 'A2': 1, 'num_propagations1': 20, 'num_propagations2': 30, 'device': 0, 'train_only': True}
# params_dict: {'alpha1': 0.14425460019673447, 'alpha2': 0.15591169025975976, 'A1': 2, 'A2': 0, 'num_propagations1': 10, 'num_propagations2': 30, 'device': 0, 'train_only': True}
# params_dict: {'alpha1': 0.5454773213405756, 'alpha2': 0.16550248474176055, 'A1': 1, 'A2': 1, 'num_propagations1': 50, 'num_propagations2': 100, 'device': 0, 'train_only': True}
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.5454773213405756, 'alpha2': 0.16550248474176055, 'A1': 1, 'A2': 1, 'num_propagations1': 50, 'num_propagations2': 100, 'device': 0, 'train_only': False}
# params_dict: {'alpha1': 0.524166574314263, 'alpha2': 0.13874388251454498, 'A1': 1, 'A2': 1, 'num_propagations1': 100, 'num_propagations2': 30, 'device': 0, 'train_only': False}
# params_dict: {'alpha1': 0.3190693285636486, 'alpha2': 0.13447222770393363, 'A1': 1, 'A2': 1, 'num_propagations1': 20, 'num_propagations2': 30, 'device': 0, 'train_only': False}
# params_dict: {'alpha1': 0.14425460019673447, 'alpha2': 0.15591169025975976, 'A1': 2, 'A2': 0, 'num_propagations1': 10, 'num_propagations2': 30, 'device': 0, 'train_only': False}
# params_dict: {'alpha1': 0.5454773213405756, 'alpha2': 0.16550248474176055, 'A1': 1, 'A2': 1, 'num_propagations1': 50, 'num_propagations2': 100, 'device': 0, 'train_only': False}
# ...

# %% [markdown]
# ## Run CaS-S

# %%
params_path = "core/CaS/cas_params_s.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha': 0.139968426673862, 'A': 1, 'num_propagations': 20, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.6108762143955151, 'A': 0, 'num_propagations': 30, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.12512721480673147, 'A': 1, 'num_propagations': 90, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.10175453377555846, 'A': 1, 'num_propagations': 60, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.139968426673862, 'A': 1, 'num_propagations': 20, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.6108762143955151, 'A': 0, 'num_propagations': 30, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.12512721480673147, 'A': 1, 'num_propagations': 90, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.10175453377555846, 'A': 1, 'num_propagations': 60, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.139968426673862, 'A': 1, 'num_propagations': 20, 'device': 0, 'labels': ['train']}
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha': 0.139968426673862, 'A': 1, 'num_propagations': 20, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.6108762143955151, 'A': 0, 'num_propagations': 30, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.12512721480673147, 'A': 1, 'num_propagations': 90, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.10175453377555846, 'A': 1, 'num_propagations': 60, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.139968426673862, 'A': 1, 'num_propagations': 20, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.6108762143955151, 'A': 0, 'num_propagations': 30, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.12512721480673147, 'A': 1, 'num_propagations': 90, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.10175453377555846, 'A': 1, 'num_propagations': 60, 'device': 0, 'labels': ['train', 'valid']}
# ...

# %% [markdown]
# # Dataset: cora

# %%
dataset = "cora"

# %% [markdown]
# ## Run CaS-Mixed

# %%
params_path = "core/CaS/cas_params.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': True}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': True}
# params_dict: {'alpha': 0.20305970175605254, 'A': 1, 'num_propagations': 50, 'labels': ['train']}
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': True}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': True}
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': False}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': False}
# params_dict: {'alpha': 0.20305970175605254, 'A': 1, 'num_propagations': 50, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.9961917624425123, 'alpha2': 0.5574100522517761, 'A1': 1, 'A2': 2, 'num_propagations1': 90, 'num_propagations2': 10, 'train_only': False}
# params_dict: {'alpha': 0.5784546711803843, 'A': 1, 'num_propagations': 90, 'labels': ['train', 'valid']}
# params_dict: {'alpha1': 0.3869533846146773, 'alpha2': 0.12930515080046406, 'A1': 0, 'A2': 2, 'num_propagations1': 100, 'num_propagations2': 40, 'train_only': False}
# ...

# %% [markdown]
# ## Run CaS-CS

# %%
params_path = "core/CaS/cas_params_cs.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.667305920773389, 'alpha2': 0.7966359700335932, 'A1': 2, 'A2': 0, 'num_propagations1': 40, 'num_propagations2': 30, 'device': 0, 'train_only': True}
# params_dict: {'alpha1': 0.7062617739283533, 'alpha2': 0.7164654713272074, 'A1': 2, 'A2': 2, 'num_propagations1': 40, 'num_propagations2': 50, 'device': 0, 'train_only': True}
# params_dict: {'alpha1': 0.35597832862955986, 'alpha2': 0.6269846450179528, 'A1': 1, 'A2': 2, 'num_propagations1': 20, 'num_propagations2': 50, 'device': 0, 'train_only': True}
# params_dict: {'alpha1': 0.6745145101009431, 'alpha2': 0.4186634191498957, 'A1': 1, 'A2': 2, 'num_propagations1': 80, 'num_propagations2': 70, 'device': 0, 'train_only': True}
# params_dict: {'alpha1': 0.667305920773389, 'alpha2': 0.7966359700335932, 'A1': 2, 'A2': 0, 'num_propagations1': 40, 'num_propagations2': 30, 'device': 0, 'train_only': True}
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha1': 0.667305920773389, 'alpha2': 0.7966359700335932, 'A1': 2, 'A2': 0, 'num_propagations1': 40, 'num_propagations2': 30, 'device': 0, 'train_only': False}
# params_dict: {'alpha1': 0.7062617739283533, 'alpha2': 0.7164654713272074, 'A1': 2, 'A2': 2, 'num_propagations1': 40, 'num_propagations2': 50, 'device': 0, 'train_only': False}
# params_dict: {'alpha1': 0.35597832862955986, 'alpha2': 0.6269846450179528, 'A1': 1, 'A2': 2, 'num_propagations1': 20, 'num_propagations2': 50, 'device': 0, 'train_only': False}
# params_dict: {'alpha1': 0.6745145101009431, 'alpha2': 0.4186634191498957, 'A1': 1, 'A2': 2, 'num_propagations1': 80, 'num_propagations2': 70, 'device': 0, 'train_only': False}
# params_dict: {'alpha1': 0.667305920773389, 'alpha2': 0.7966359700335932, 'A1': 2, 'A2': 0, 'num_propagations1': 40, 'num_propagations2': 30, 'device': 0, 'train_only': False}
# ...

# %% [markdown]
# ## Run CaS-S

# %%
params_path = "core/CaS/cas_params_s.json"

# %% [markdown]
# ### Train only

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha': 0.6029200056052838, 'A': 1, 'num_propagations': 20, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.8542862864363261, 'A': 1, 'num_propagations': 50, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.8262843686606611, 'A': 0, 'num_propagations': 70, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.13179993586259012, 'A': 1, 'num_propagations': 10, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.6029200056052838, 'A': 1, 'num_propagations': 20, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.8542862864363261, 'A': 1, 'num_propagations': 50, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.8262843686606611, 'A': 0, 'num_propagations': 70, 'device': 0, 'labels': ['train']}
# params_dict: {'alpha': 0.13179993586259012, 'A': 1, 'num_propagations': 10, 'device': 0, 'labels': ['train']}
# ...

# %% [markdown]
# ### Train and valid

# %%
for model_name in ["MLP", "GCN", "SAGE", "RevGAT"]:
    # !python -m core.runCaS dataset $dataset gnn.model.name $model_name seed $SEED runs $RUNS cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name MLP seed $SEED runs $RUNS gnn.train.use_emb "node2vec" cas.train_only False cas.cas_params_path $params_path
# !python -m core.runCaS dataset $dataset gnn.model.name RevGAT seed $SEED runs $RUNS cas.use_lm_pred True cas.train_only False cas.cas_params_path $params_path
# Out:
# params_dict: {'alpha': 0.6029200056052838, 'A': 1, 'num_propagations': 20, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.8542862864363261, 'A': 1, 'num_propagations': 50, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.8262843686606611, 'A': 0, 'num_propagations': 70, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.13179993586259012, 'A': 1, 'num_propagations': 10, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.6029200056052838, 'A': 1, 'num_propagations': 20, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.8542862864363261, 'A': 1, 'num_propagations': 50, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.8262843686606611, 'A': 0, 'num_propagations': 70, 'device': 0, 'labels': ['train', 'valid']}
# params_dict: {'alpha': 0.13179993586259012, 'A': 1, 'num_propagations': 10, 'device': 0, 'labels': ['train', 'valid']}
# ...
